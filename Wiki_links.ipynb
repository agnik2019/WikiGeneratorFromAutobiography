# %% [markdown]
# # Learn all the formats of Wikipedia scrapping

# %%
#!pip install requests

# %%
#!pip install beautifulsoup4

# %%
# import modules
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://en.wikipedia.org/wiki/Mahatma_Gandhi'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
response = requests.get(url, headers=headers)
#print(response.status_code)
# Out:
# 200

# %%
# soup = BeautifulSoup(response.content, 'html.parser')

# title = soup.find(id="firstHeading")
# print(title.string)
# Out:
# Mahatma Gandhi

# %% [markdown]
# ## Finding all the hyperlinks of a wikipedia page

# %%
allLinks = soup.find(id="bodyContent").find_all("a")
linkToScrape = []
for link in allLinks:
    if link.get('href') is not None and link.get('href').find("/wiki/")== 0: 
        linkToScrape.append(link)

print(len(linkToScrape))
# print the urls of linkToScrape
# https://en.wikipedia.org/wiki/Nationalism#Anti-colonial_nationalism
url = "https://en.wikipedia.org"
urls = []
for link in linkToScrape:
    urls.append(url+link['href'])
print(urls)
# Out:
# 3529

# %%
with open('scrapped_gandhi_links.txt','w') as f:
    f.write('\n'.join(urls))

# %% [markdown]
# ## Fetching all the paragraphs of wikipedia page

# %%
url = 'https://simple.wikipedia.org/wiki/Mahatma_Gandhi'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
page = requests.get(url, headers=headers)
soup = BeautifulSoup(page.content, 'html.parser') 
list(soup.children)
 
for i in range(len(soup.find_all('p'))):
    print(soup.find_all('p')[i].get_text())
    print('\n\n')
# Out:
# 				Pages for logged out editors learn more
#
#
#
#
# Mohandas Karamchand Gandhi (/ˈɡɑːndi, ˈɡændi/;[2] GAHN-dee; 2 October 1869 – 30 January 1948) was a leader of nationalism in British-ruled India. He is more commonly called Mahatma Gandhi;[3] mahatma is an honorific meaning "great-soul" or "venerable" in Sanskrit. He was first called this in 1914 in South Africa. He is also called Bapu in India (Gujarati endearment for "father", "papa").
#
#
#
#
# He was the Martyr of the Nation since 1948. Rabindranath Tagore gave him the title of  'Mahatma'.[4]
#
#
#
#
# Gandhi was one of the most important people involved in the movement for the independence of India. He was a non-violent activist, who led the independence movement through a non-violent protest.
#
#
#
#
# ...

# %% [markdown]
# ## Working with wikipedia tables

# %%
import pandas as pd
url = "https://en.wikipedia.org/wiki/1999%E2%80%932000_FA_Premier_League"
tables = pd.read_html(url) 
print(tables)
tables[3]
# Out:
# [    0                                                  1
# 0 NaN  This article includes a list of general refere...,                        0                                                  1
# 0                 Season                                          1999–2000
# 1                  Dates                        7 August 1999 – 14 May 2000
# 2              Champions  Manchester United6th Premier League title13th ...
# 3              Relegated                WimbledonSheffield WednesdayWatford
# 4       Champions League               Manchester UnitedArsenalLeeds United
# 5               UEFA Cup                     LiverpoolChelseaLeicester City
# 6          Intertoto Cup                           Aston VillaBradford City
# 7         Matches played                                                380
# 8           Goals scored                             1,060 (2.79 per match)
# 9         Top goalscorer                          Kevin Phillips (30 goals)
# ...
