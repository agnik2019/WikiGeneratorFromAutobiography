# %%
#!pip install keybert

# %%
#!pip install bert-extractive-summarizer

# %%
import re
import os, os.path
import fnmatch
import json
import collections
import glob
import json

# %%
book ="SOMEWT"
def get_year_to_content(book):
    dir_path = './%s/part'% book
    date_dict = {}
    year_mode_dict = {}
    # for part in range(1,Parts+1):
    rootdir = r"C:\Users\hp\OneDrive\Documents\topic_coherence\%s"% book
    part = 1
    for path in glob.glob(f'{rootdir}/*/**/', recursive=True):
        x = 1
        #print("part:" + str(part))
        date_dict[str(part)] = {}
        year_mode_dict[str(part)] = {}
        #print(dir_path + str(part) + '/')
        no_of_chapters = len(fnmatch.filter(os.listdir(dir_path + str(part) + '/'), '*.txt'))
    #     print('no.of_chapters:' + str(no_of_chapters))
        while x <= no_of_chapters:
            target_x = no_of_chapters+1
            for i in range(x,target_x):
                #print("chapter:" + str(i))
                with open(dir_path + str(part) + '/chapter'+ str(i) + '.txt', 'r', encoding='utf-8') as content_file:
                    content = content_file.read()

                regex= "\d{4}"
                dates = re.findall(regex, content)
                mdates = []
                year_list = []
                try:
                    for date in dates:
                        if int(date) < 1960 and int(date) > 1800:                    
                            #print date
                            year_list.append(date)
                            mdates.append(date)                       
                except:
                    pass
                date_dict[str(part)][str(i)] = mdates
                try:
                    year_mode_dict[str(part)][str(i)] = max(set(year_list), key=year_list.count)
                except:
                    year_mode_dict[str(part)][str(i)] = -1
            x = target_x
            part += 1

    # assigning chapter the date with closest chapter
    def closest(lst, K):
        return lst[min(range(len(lst)), key = lambda i: abs(lst[i]-K))]


    #for part in range(1,Parts+1):
    part = 1
    for path in glob.glob(f'{rootdir}/*/**/', recursive=True):
        x = 1
        # checking which chapters has date assigned
        no_of_chapters = len(fnmatch.filter(os.listdir(dir_path + str(part) + '/'), '*.txt'))
        chapters_with_date = []
        while x <= no_of_chapters:
            target_x = no_of_chapters+1
            for i in range(x,target_x):
                # print("chapter:" + str(i))
                if year_mode_dict[str(part)][str(i)] != -1:
                    chapters_with_date.append(i)
            x = target_x
        x = 1
        # assigning date to chapter which is closest to it
        while x <= no_of_chapters:
            target_x = no_of_chapters+1
            for i in range(x,target_x):
                #print("chapter:" + str(i))
                k = closest(chapters_with_date,i)
                #print("K:",k)
                year_mode_dict[str(part)][str(i)] = year_mode_dict[str(part)][str(k)]
            x = target_x
        part += 1

    rootdir = r"C:\Users\hp\OneDrive\Documents\topic_coherence\SOMEWT"
    year_to_chap = collections.defaultdict(list)  # year -> list of folder paths
    for key in year_mode_dict.keys():
        folder = f"{rootdir}\part{key}"
        for k2 in year_mode_dict[key].keys():
            file = folder
            file += f"\chapter{k2}.txt"
            val = year_mode_dict[key][k2]
            year_to_chap[val].append(file)

    #print(year_to_chap)
    year_to_content = {}
    for key in year_to_chap.keys():
    #     print(key)
        content = ""
        for l in year_to_chap[key]:
    #         print(l)
            with open(l,'r') as f:
                content += f.read()
            year_to_content[key] = content

    return year_to_content

# %%
year_to_content = get_year_to_content(book)
sort_keys = [int(k) for k in year_to_content.keys()]
sort_keys.sort()
sort_keys = [str(k) for k in year_to_content.keys()]

year_to_content2 = {}
for i in sorted(sort_keys):
    year_to_content2[i]= year_to_content[i]
with open("year_to_content.json", "w") as outfile:
    json.dump(year_to_content2, outfile)

# %% [markdown]
# # Keyword Extraction
# ### Finally, we get the year to content mapping
# Now we will see keyword extraction first

# %%
def extract_keyword_from_date(doc):
    from keybert import KeyBERT
    kw_model = KeyBERT()
    onegram_keywords = kw_model.extract_keywords(doc,keyphrase_ngram_range=(1, 1),top_n=3,stop_words='english',use_mmr = True, diversity=0.5)
    twogram_keywords = kw_model.extract_keywords(doc,keyphrase_ngram_range=(1, 2),top_n=3,stop_words='english',use_mmr = True, diversity=0.5)
    threegram_keywords = kw_model.extract_keywords(doc,keyphrase_ngram_range=(3, 3),top_n=3,stop_words='english',use_mmr = True, diversity=0.5)
    onegram_keywords2 = [i[0] for i in onegram_keywords]
    twogram_keywords2 = [i[0] for i in twogram_keywords]
    threegram_keywords2 = [i[0] for i in threegram_keywords]
    return onegram_keywords2,twogram_keywords2,threegram_keywords2

# %% [markdown]
# ## Text Summarization with Bert

# %%
from summarizer import Summarizer,TransformerSummarizer
year_to_summarizer = {}

bert_model = Summarizer()

for key in year_to_content.keys():
    year_to_summarizer[key] = ''.join(bert_model(year_to_content[key], min_length=40))
# Out:
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# ### Text Summarization with GPT-2

# %%
# GPT2_model = TransformerSummarizer(transformer_type="GPT2",transformer_model_key="gpt2-medium")
# full = ''.join(GPT2_model(doc, min_length=40))
# print(full)

# %%
sort_keys = [int(k) for k in year_to_summarizer.keys()]
sort_keys.sort()
sort_keys = [str(k) for k in year_to_summarizer.keys()]

year_to_summarizer2 = {}
for i in sorted(sort_keys):
    year_to_summarizer2[i]= year_to_summarizer[i]

# %%
with open("year_to_summarizer.json", "w") as outfile:
    json.dump(year_to_summarizer2, outfile)

# %%
with open('year_to_summarizer.json') as json_file:
    year_to_summarizer = json.load(json_file)

# %%
year_to_summarizer.keys()
# Out:
# dict_keys(['1857', '1869', '1887', '1888', '1890', '1891', '1893', '1894', '1896', '1897', '1898', '1900', '1901', '1904', '1906', '1908', '1911', '1912', '1914', '1915', '1917', '1919', '1920', '1921', '1924'])

# %%
year_to_content.keys()
# Out:
# dict_keys(['1869', '1887', '1890', '1891', '1857', '1893', '1924', '1888', '1894', '1896', '1897', '1906', '1901', '1898', '1914', '1904', '1900', '1912', '1911', '1915', '1917', '1919', '1908', '1920', '1921'])

# %%
# timeline_content_map = get_timeline_interval_content(5)

# %% [markdown]
# ## year_to_keywords json

# %%
with open("year_to_content.json") as outfile:
    year_to_content = json.load(outfile)

# %%
with open('year_to_summarizer.json') as json_file:
    year_to_summarizer = json.load(json_file)

# %%
year = {
        "chapterwise": {
            "1gram":[],
            "2gram":[],
            "3gram":[]
        },
        "summarywise":{
            "1gram":[],
            "2gram":[],
            "3gram":[]     
        }
}

# data = {}
# # initialization
# for key in year_to_content.keys():
#     data[key] = year

# %%
import copy
data = {}
for key in year_to_content.keys():
    onegram_keywords,twogram_keywords,threegram_keywords = extract_keyword_from_date(year_to_summarizer[key])
    onegram_keywords2,twogram_keywords2,threegram_keywords2 = extract_keyword_from_date(year_to_content[key])
    data = copy.deepcopy(data)
    data[key] = year
    data[key]['chapterwise']['1gram'] = onegram_keywords2
    data[key]["chapterwise"]['2gram'] = twogram_keywords2
    data[key]["chapterwise"]['3gram'] = threegram_keywords2
    data[key]["summarywise"]['1gram'] = onegram_keywords
    data[key]["summarywise"]['2gram'] = twogram_keywords
    data[key]["summarywise"]['3gram'] = threegram_keywords
    print(f"{key}  -> {onegram_keywords}   -> {data[key]['chapterwise']['1gram']}")
# Out:
# 1857  -> ['dadabhai', 'reading', 'venerable']   -> ['law', 'hindu', 'practice']
# 1869  -> ['gandhi', 'gujarati', 'pity']   -> ['gandhi', 'karamchand', 'widowed']
# 1887  -> ['meat', 'acquaintance', 'weaknesses']   -> ['friendships', 'despaired', 'eldest']
# 1888  -> ['transvaal', 'exempted', 'walk']   -> ['transvaal', 'exemption', 'satyagraha']
# 1890  -> ['vegetarianism', 'definitions', 'vow']   -> ['vegetarianism', 'internally', 'intervals']
# 1891  -> ['communion', 'barristers', 'deferred']   -> ['dinners', 'deferred', 'rupee']
# 1893  -> ['grief', 'raychandbhai', 'affidavit']   -> ['sea', 'mehta', 'agitation']
# 1894  -> ['pay', 'mahatmaship', 'collections']   -> ['congress', 'natal', 'pandit']
# 1896  -> ['servant', 'urdu', '1896']   -> ['servant', 'household', 'madras']
# 1897  -> ['parsi', 'durban', 'manners']   -> ['dress', 'hindu', 'banias']
# 1898  -> ['diet', 'restraint', 'proverb']   -> ['writings', 'dietetics', 'gujarati']
# 1900  -> ['brahmacharya', 'thoughts', 'zulu']   -> ['zulus', 'rebellion', 'pondered']
# 1901  -> ['lokamanya', 'delegates', 'untouchability']   -> ['gandhi', 'mauritius', 'session']
# 1904  -> ['plague', 'municipality', 'deposit']   -> ['plague', 'municipality', 'submit']
# 1906  -> ['vows', 'brahmacharya', 'gladstone']   -> ['brahmacharya', 'vows', 'gladstone']
# 1908  -> ['gandhi', 'boycott', 'deliberations']   -> ['punjab', 'assassination', 'disobedience']
# 1911  -> ['urdu', 'teach', 'tolstoy']   -> ['teaching', 'tolstoy', 'gujarati']
# 1912  -> ['kasturbai', 'diet', 'restraint']   -> ['brahmacharya', 'milk', 'vegetarianism']
# 1914  -> ['prejudice', 'stenographer', 'consult']   -> ['clerk', 'transvaal', 'permit']
# 1915  -> ['gujaratis', 'pilgrimage', 'reconciled']   -> ['hyderabad', 'mahatmaji', 'pilgrims']
# 1917  -> ['bihar', 'champaran', 'indigo']   -> ['indigo', 'champaran', 'plantations']
# 1919  -> ['pledges', 'fasting', 'mills']   -> ['strike', 'rowdyism', 'helplessly']
# 1920  -> ['cloth', 'swadeshi', 'demand']   -> ['swadeshi', 'mills', 'labouring']
# 1921  -> ['salvation', 'purification', 'ahimsa']   -> ['congress', 'experiments', 'shraddhanandji']
# 1924  -> ['durban', 'intention', 'lawyer']   -> ['incident', 'durban', 'adamji']

# %%
data
# Out:
# {'1857': {'chapterwise': {'1gram': ['law', 'hindu', 'practice'],
#    '2gram': ['practise law', 'studied shakespeare', 'know indian'],
#    '3gram': ['learnt indian law',
#     'making successful lawyer',
#     'legal maxims did']},
#   'summarywise': {'1gram': ['dadabhai', 'reading', 'venerable'],
#    '2gram': ['indian history', 'introduction dadabhai', 'read kaye'],
#    '3gram': ['introduction dadabhai thought',
#     'know indian history',
#     'hold read books']}},
#  '1869': {'chapterwise': {'1gram': ['gandhi', 'karamchand', 'widowed'],
#    '2gram': ['gandhi father', 'leave porbandar', 'children marry'],
#    '3gram': ['kaba gandhi father',
#     'compelled leave porbandar',
#     'kathiawad states uttamchand']},
#   'summarywise': {'1gram': ['gandhi', 'gujarati', 'pity'],
#    '2gram': ['gandhi grandfather', 'bania caste', 'vow illness'],
#    '3gram': ['gandhis belong bania',
#     'wife pensioner rajkot',
#     'chandrayana2 vow illness']}},
#  '1887': {'chapterwise': {'1gram': ['friendships', 'despaired', 'eldest'],
#    '2gram': ['react friendship', 'weakness regarded', 'eldest brother'],
#    '3gram': ['friendship proved failure',
#     'brother uneasy refused',
#     'abusing religion ancestors']},
#   'summarywise': {'1gram': ['meat', 'acquaintance', 'weaknesses'],
#    '2gram': ['taking meat', 'friend dared', 'explained weak'],
#    '3gram': ['insistence abjuring meat',
#     'stolen coppers got',
#     'friend dared opinion']}},
#  '1888': {'chapterwise': {'1gram': ['transvaal', 'exemption', 'satyagraha'],
#    '2gram': ['indians transvaal', 'history satyagraha', 'laws coloured'],
#    '3gram': ['condition indians transvaal',
#     'law enacted 1888',
#     'asiatics laws coloured']},
#   'summarywise': {'1gram': ['transvaal', 'exempted', 'walk'],
#    '2gram': ['indians transvaal', 'favour exempted', 'coates happened'],
#    '3gram': ['condition indians transvaal',
#     'coates happened passing',
#     'tax fee entry']}},
#  '1890': {'chapterwise': {'1gram': ['vegetarianism',
#     'internally',
#     'intervals'],
#    '2gram': ['vegetarianism morality', 'man eats', 'changes internal'],
#    '3gram': ['intellectually converted vegetarianism',
#     'giving health demanded',
#     'changes internal external']},
#   'summarywise': {'1gram': ['vegetarianism', 'definitions', 'vow'],
#    '2gram': ['interpretation meat', 'diet expensive', 'external treatment'],
#    '3gram': ['interpretation meat according',
#     'make changes diet',
#     'went external treatment']}},
#  '1891': {'chapterwise': {'1gram': ['dinners', 'deferred', 'rupee'],
#    '2gram': ['attending dinners', 'cost drink', 'terms legislate'],
#    '3gram': ['terms attending dinners',
#     'deferred saying purpose',
#     'bombay expecting remittance']},
#   'summarywise': {'1gram': ['communion', 'barristers', 'deferred'],
#    '2gram': ['dinner barristers', 'helplessness fear', 'retained curriculum'],
#    '3gram': ['dinner barristers question',
#     'chapter needed helplessness',
#     'vegetarianism vegetarian courses']}},
#  '1893': {'chapterwise': {'1gram': ['sea', 'mehta', 'agitation'],
#    '2gram': ['troubled caste', 'arabian sea', 'ashore warned'],
#    '3gram': ['occasion troubled caste',
#     'ashore warned harbour',
#     'porridge cocoa replace']},
#   'summarywise': {'1gram': ['grief', 'raychandbhai', 'affidavit'],
#    '2gram': ['grief', 'raychandbhai did', 'stranded bombay'],
#    '3gram': ['grief dr mehta',
#     'friendship known shatavadhani',
#     'remembering attending things']}},
#  '1894': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['pay', 'mahatmaship', 'collections'],
#    '2gram': ['gave indentured',
#     'collection considerably',
#     'legislation antagonism'],
#    '3gram': ['collection considerably facilitated',
#     'lawyer remained subordinate',
#     'tax indentured indians']}},
#  '1896': {'chapterwise': {'1gram': ['servant', 'household', 'madras'],
#    '2gram': ['servant friend', 'household keeping', 'induce barristers'],
#    '3gram': ['servant essential household',
#     'deceived jealous office',
#     'harmed indian doubts']},
#   'summarywise': {'1gram': ['servant', 'urdu', '1896'],
#    '2gram': ['urdu munshi', 'servant essential', 'difficult grievance'],
#    '3gram': ['servant essential household',
#     'leave calcutta abruptly',
#     'abolished charge congress']}},
#  '1897': {'chapterwise': {'1gram': ['dress', 'hindu', 'banias'],
#    '2gram': ['dress adopted', 'hindu wife', 'banias parsis'],
#    '3gram': ['dress adopted wife',
#     'kathiawad banias parsis',
#     'indian slovenly habits']},
#   'summarywise': {'1gram': ['parsi', 'durban', 'manners'],
#    '2gram': ['parsi style', 'port durban', 'passengers prayers'],
#    '3gram': ['adopted parsi style',
#     'anchor port durban',
#     'joined passengers prayers']}},
#  '1898': {'chapterwise': {'1gram': ['writings', 'dietetics', 'gujarati'],
#    '2gram': ['readers indian', 'treatment dietetics', 'booklet reason'],
#    '3gram': ['indian opinion published',
#     'dietetics carried place',
#     'booklet reason alter']},
#   'summarywise': {'1gram': ['diet', 'restraint', 'proverb'],
#    '2gram': ['indian proverb', 'restraint diet', 'warning adopting'],
#    '3gram': ['indian proverb man',
#     'restraint diet quantity',
#     'warning adopting remedy']}},
#  '1900': {'chapterwise': {'1gram': ['zulus', 'rebellion', 'pondered'],
#    '2gram': ['zulu rebellion', 'pondered brahmacharya', 'nursing wounded'],
#    '3gram': ['zulus marching wounded',
#     'vividness rebellion did',
#     'pondered brahmacharya implications']},
#   'summarywise': {'1gram': ['brahmacharya', 'thoughts', 'zulu'],
#    '2gram': ['praise brahmacharya',
#     'zulu rebellion',
#     'consistent imagination'],
#    '3gram': ['extravagant praise brahmacharya',
#     'lock undesirable thoughts',
#     'zulu rebellion new']}},
#  '1901': {'chapterwise': {'1gram': ['gandhi', 'mauritius', 'session'],
#    '2gram': ['congress bombay', 'mr wacha', 'dining meant'],
#    '3gram': ['congress met calcutta',
#     'sailed home mauritius',
#     'wacha mr sir']},
#   'summarywise': {'1gram': ['lokamanya', 'delegates', 'untouchability'],
#    '2gram': ['tamil delegates', 'session prolonged', 'mauritius ports'],
#    '3gram': ['volunteers tamil delegates',
#     'session prolonged conditions',
#     'mauritius ports boat']}},
#  '1904': {'chapterwise': {'1gram': ['plague', 'municipality', 'submit'],
#    '2gram': ['regarding plague', 'municipality help', 'work indian'],
#    '3gram': ['work regarding plague',
#     'solicitude white citizens',
#     'omission commission indians']},
#   'summarywise': {'1gram': ['plague', 'municipality', 'deposit'],
#    '2gram': ['regarding plague',
#     'commission indians',
#     'municipality hesitated'],
#    '3gram': ['black plague dealt',
#     'submit theâ municipality',
#     'banks means anxious']}},
#  '1906': {'chapterwise': {'1gram': ['brahmacharya', 'vows', 'gladstone'],
#    '2gram': ['brahmacharya willed', 'raychandbhai love', 'gladstone husband'],
#    '3gram': ['brahmacharya vow wedded',
#     'raychandbhai love mrs',
#     'gladstone devotion husband']},
#   'summarywise': {'1gram': ['vows', 'brahmacharya', 'gladstone'],
#    '2gram': ['vow brahmacharya', 'mrs gladstone', 'break household'],
#    '3gram': ['taking brahmacharya vow',
#     'servant asked relation',
#     'read mrs gladstone']}},
#  '1908': {'chapterwise': {'1gram': ['punjab', 'assassination', 'disobedience'],
#    '2gram': ['happened punjab',
#     'disobedience jalianwala',
#     'government confinement'],
#    '3gram': ['punjab government confinement',
#     'jalianwala bagh massacre',
#     'person misunderstand impatient']},
#   'summarywise': {'1gram': ['gandhi', 'boycott', 'deliberations'],
#    '2gram': ['happened punjab', 'boycott committee', 'regard religious'],
#    '3gram': ['responsible happened punjab',
#     'boycott committee absolutely',
#     'stopped cow slaughter']}},
#  '1911': {'chapterwise': {'1gram': ['teaching', 'tolstoy', 'gujarati'],
#    '2gram': ['literary training', 'tolstoy farm', 'gujarati hindu'],
#    '3gram': ['literary training hindi',
#     'tolstoy farm incidentally',
#     'school hours kept']},
#   'summarywise': {'1gram': ['urdu', 'teach', 'tolstoy'],
#    '2gram': ['teach musalman', 'urdu script', 'successful literary'],
#    '3gram': ['literary training difficult',
#     'musalman boys urdu',
#     'tolstoy farm incidentally']}},
#  '1912': {'chapterwise': {'1gram': ['brahmacharya', 'milk', 'vegetarianism'],
#    '2gram': ['diet brahmacharya', 'milk interests', 'kasturbai illness'],
#    '3gram': ['brahmacharya giving milk',
#     'books vegetarianism strengthened',
#     'kasturbai illness instrumental']},
#   'summarywise': {'1gram': ['kasturbai', 'diet', 'restraint'],
#    '2gram': ['kasturbai illness', 'consciously unclean', 'cows buffaloes'],
#    '3gram': ['chapter kasturbai illness',
#     'necessity avoiding milk',
#     'restraint used fasting']}},
#  '1914': {'chapterwise': {'1gram': ['clerk', 'transvaal', 'permit'],
#    '2gram': ['indian clerks', 'transvaal permit', 'approached typewriting'],
#    '3gram': ['transvaal permit personal',
#     'clerks work impossible',
#     'editor indian opinion']},
#   'summarywise': {'1gram': ['prejudice', 'stenographer', 'consult'],
#    '2gram': ['indian clerks', 'typewriting knew', 'urged scolding'],
#    '3gram': ['indian clerks like',
#     'presence wife suffered',
#     'created urged scolding']}},
#  '1915': {'chapterwise': {'1gram': ['hyderabad', 'mahatmaji', 'pilgrims'],
#    '2gram': ['phoenix ashram', 'prasad history', 'poet shraddhanandji'],
#    '3gram': ['ashram settle phoenix',
#     'poet shraddhanandji principal',
#     'andrews advised gurukul']},
#   'summarywise': {'1gram': ['gujaratis', 'pilgrimage', 'reconciled'],
#    '2gram': ['arrived gujaratis', 'reconciled protest', 'expenses ashram'],
#    '3gram': ['arrived gujaratis let',
#     'member opposition justified',
#     'expenses ashram house']}},
#  '1917': {'chapterwise': {'1gram': ['indigo', 'champaran', 'plantations'],
#    '2gram': ['indigo plantations', 'champaran hardly', 'known tinkathia'],
#    '3gram': ['used indigo plantations',
#     'champaran hardly notion',
#     'land king janaka']},
#   'summarywise': {'1gram': ['bihar', 'champaran', 'indigo'],
#    '2gram': ['indigo plantations', 'poor rajkumar', 'visit champaran'],
#    '3gram': ['used indigo plantations',
#     'rajkumar menial strict',
#     'personally visit champaran']}},
#  '1919': {'chapterwise': {'1gram': ['strike', 'rowdyism', 'helplessly'],
#    '2gram': ['hand agitation', 'strike weaken', 'failed enlist'],
#    '3gram': ['experience gigantic strike',
#     'pledges people resisted',
#     'understand duty keeping']},
#   'summarywise': {'1gram': ['pledges', 'fasting', 'mills'],
#    '2gram': ['minister pledge', 'leave mills', 'monstrous fast'],
#    '3gram': ['hands taken pledge',
#     'employment strikers municipality',
#     'food monstrous fast']}},
#  '1920': {'chapterwise': {'1gram': ['swadeshi', 'mills', 'labouring'],
#    '2gram': ['swadeshi agitation', 'philanthropy profit', 'new mills'],
#    '3gram': ['exploited swadeshi movement',
#     'mills harm good',
#     'shareholders price article']},
#   'summarywise': {'1gram': ['cloth', 'swadeshi', 'demand'],
#    '2gram': ['swadeshi cloth', 'india production', 'congratulated mills'],
#    '3gram': ['india production cloth',
#     'swadeshi largely resolves',
#     'congratulated mills want']}},
#  '1921': {'chapterwise': {'1gram': ['congress',
#     'experiments',
#     'shraddhanandji'],
#    '2gram': ['history congress', 'chapters close', 'instinctively refuses'],
#    '3gram': ['veteran congress leaders',
#     'bring chapters close',
#     'experiments hardly regarded']},
#   'summarywise': {'1gram': ['salvation', 'purification', 'ahimsa'],
#    '2gram': ['purification self', 'faithful narrative', 'history congress'],
#    '3gram': ['indescribable lustre truth',
#     'self purification observance',
#     'congress leaders hardly']}},
#  '1924': {'chapterwise': {'1gram': ['incident', 'durban', 'adamji'],
#    '2gram': ['durban court', 'catholic acquaintance', 'indians traveling'],
#    '3gram': ['contact christian indians',
#     'pretoria asked sheth',
#     'letter narrating happened']},
#   'summarywise': {'1gram': ['durban', 'intention', 'lawyer'],
#    '2gram': ['book durban', 'intention proceeding', 'confidential relatives'],
#    '3gram': ['refused book durban',
#     'railway informed abdulla',
#     'lawyer saying preparations']}}}

# %%
with open("year_to_all_keywords.json", "w") as outfile:
    json.dump(data, outfile)

# %% [markdown]
# ## Taking care of temporal datas

# %%
with open('year_to_all_keywords.json') as json_file:
    year_to_all_keywords = json.load(json_file)
    
with open("year_to_content.json") as outfile:
    year_to_content = json.load(outfile)

# %%
year_to_all_keywords
# Out:
# {'1869': {'chapterwise': {'1gram': ['gandhi', 'gujarati', 'pity'],
#    '2gram': ['gandhi grandfather', 'bania caste', 'vow illness'],
#    '3gram': ['gandhis belong bania',
#     'wife pensioner rajkot',
#     'chandrayana2 vow illness']},
#   'summarywise': {'1gram': ['gandhi', 'gujarati', 'pity'],
#    '2gram': ['gandhi grandfather', 'bania caste', 'vow illness'],
#    '3gram': ['gandhis belong bania',
#     'wife pensioner rajkot',
#     'chandrayana2 vow illness']}},
#  '1887': {'chapterwise': {'1gram': ['meat', 'acquaintance', 'weaknesses'],
#    '2gram': ['taking meat', 'friend dared', 'explained weak'],
#    '3gram': ['insistence abjuring meat',
#     'stolen coppers got',
#     'friend dared opinion']},
#   'summarywise': {'1gram': ['meat', 'acquaintance', 'weaknesses'],
#    '2gram': ['taking meat', 'friend dared', 'explained weak'],
#    '3gram': ['insistence abjuring meat',
#     'stolen coppers got',
#     'friend dared opinion']}},
#  '1890': {'chapterwise': {'1gram': ['vegetarianism', 'definitions', 'vow'],
#    '2gram': ['interpretation meat', 'diet expensive', 'external treatment'],
#    '3gram': ['interpretation meat according',
#     'make changes diet',
#     'went external treatment']},
#   'summarywise': {'1gram': ['vegetarianism', 'definitions', 'vow'],
#    '2gram': ['interpretation meat', 'diet expensive', 'external treatment'],
#    '3gram': ['interpretation meat according',
#     'make changes diet',
#     'went external treatment']}},
#  '1891': {'chapterwise': {'1gram': ['communion', 'barristers', 'deferred'],
#    '2gram': ['dinner barristers', 'helplessness fear', 'retained curriculum'],
#    '3gram': ['dinner barristers question',
#     'chapter needed helplessness',
#     'vegetarianism vegetarian courses']},
#   'summarywise': {'1gram': ['communion', 'barristers', 'deferred'],
#    '2gram': ['dinner barristers', 'helplessness fear', 'retained curriculum'],
#    '3gram': ['dinner barristers question',
#     'chapter needed helplessness',
#     'vegetarianism vegetarian courses']}},
#  '1857': {'chapterwise': {'1gram': ['dadabhai', 'reading', 'venerable'],
#    '2gram': ['indian history', 'introduction dadabhai', 'read kaye'],
#    '3gram': ['introduction dadabhai thought',
#     'know indian history',
#     'hold read books']},
#   'summarywise': {'1gram': ['dadabhai', 'reading', 'venerable'],
#    '2gram': ['indian history', 'introduction dadabhai', 'read kaye'],
#    '3gram': ['introduction dadabhai thought',
#     'know indian history',
#     'hold read books']}},
#  '1893': {'chapterwise': {'1gram': ['grief', 'raychandbhai', 'affidavit'],
#    '2gram': ['grief', 'raychandbhai did', 'stranded bombay'],
#    '3gram': ['grief dr mehta',
#     'friendship known shatavadhani',
#     'remembering attending things']},
#   'summarywise': {'1gram': ['grief', 'raychandbhai', 'affidavit'],
#    '2gram': ['grief', 'raychandbhai did', 'stranded bombay'],
#    '3gram': ['grief dr mehta',
#     'friendship known shatavadhani',
#     'remembering attending things']}},
#  '1924': {'chapterwise': {'1gram': ['durban', 'intention', 'lawyer'],
#    '2gram': ['book durban', 'intention proceeding', 'confidential relatives'],
#    '3gram': ['refused book durban',
#     'railway informed abdulla',
#     'lawyer saying preparations']},
#   'summarywise': {'1gram': ['durban', 'intention', 'lawyer'],
#    '2gram': ['book durban', 'intention proceeding', 'confidential relatives'],
#    '3gram': ['refused book durban',
#     'railway informed abdulla',
#     'lawyer saying preparations']}},
#  '1888': {'chapterwise': {'1gram': ['transvaal', 'exempted', 'walk'],
#    '2gram': ['indians transvaal', 'favour exempted', 'coates happened'],
#    '3gram': ['condition indians transvaal',
#     'coates happened passing',
#     'tax fee entry']},
#   'summarywise': {'1gram': ['transvaal', 'exempted', 'walk'],
#    '2gram': ['indians transvaal', 'favour exempted', 'coates happened'],
#    '3gram': ['condition indians transvaal',
#     'coates happened passing',
#     'tax fee entry']}},
#  '1894': {'chapterwise': {'1gram': ['pay', 'mahatmaship', 'collections'],
#    '2gram': ['gave indentured',
#     'collection considerably',
#     'legislation antagonism'],
#    '3gram': ['collection considerably facilitated',
#     'lawyer remained subordinate',
#     'tax indentured indians']},
#   'summarywise': {'1gram': ['pay', 'mahatmaship', 'collections'],
#    '2gram': ['gave indentured',
#     'collection considerably',
#     'legislation antagonism'],
#    '3gram': ['collection considerably facilitated',
#     'lawyer remained subordinate',
#     'tax indentured indians']}},
#  '1896': {'chapterwise': {'1gram': ['servant', 'urdu', '1896'],
#    '2gram': ['urdu munshi', 'servant essential', 'difficult grievance'],
#    '3gram': ['servant essential household',
#     'leave calcutta abruptly',
#     'abolished charge congress']},
#   'summarywise': {'1gram': ['servant', 'urdu', '1896'],
#    '2gram': ['urdu munshi', 'servant essential', 'difficult grievance'],
#    '3gram': ['servant essential household',
#     'leave calcutta abruptly',
#     'abolished charge congress']}},
#  '1897': {'chapterwise': {'1gram': ['parsi', 'durban', 'manners'],
#    '2gram': ['parsi style', 'port durban', 'passengers prayers'],
#    '3gram': ['adopted parsi style',
#     'anchor port durban',
#     'joined passengers prayers']},
#   'summarywise': {'1gram': ['parsi', 'durban', 'manners'],
#    '2gram': ['parsi style', 'port durban', 'passengers prayers'],
#    '3gram': ['adopted parsi style',
#     'anchor port durban',
#     'joined passengers prayers']}},
#  '1906': {'chapterwise': {'1gram': ['vows', 'brahmacharya', 'gladstone'],
#    '2gram': ['vow brahmacharya', 'mrs gladstone', 'break household'],
#    '3gram': ['taking brahmacharya vow',
#     'servant asked relation',
#     'read mrs gladstone']},
#   'summarywise': {'1gram': ['vows', 'brahmacharya', 'gladstone'],
#    '2gram': ['vow brahmacharya', 'mrs gladstone', 'break household'],
#    '3gram': ['taking brahmacharya vow',
#     'servant asked relation',
#     'read mrs gladstone']}},
#  '1901': {'chapterwise': {'1gram': ['lokamanya',
#     'delegates',
#     'untouchability'],
#    '2gram': ['tamil delegates', 'session prolonged', 'mauritius ports'],
#    '3gram': ['volunteers tamil delegates',
#     'session prolonged conditions',
#     'mauritius ports boat']},
#   'summarywise': {'1gram': ['lokamanya', 'delegates', 'untouchability'],
#    '2gram': ['tamil delegates', 'session prolonged', 'mauritius ports'],
#    '3gram': ['volunteers tamil delegates',
#     'session prolonged conditions',
#     'mauritius ports boat']}},
#  '1898': {'chapterwise': {'1gram': ['diet', 'restraint', 'proverb'],
#    '2gram': ['indian proverb', 'restraint diet', 'warning adopting'],
#    '3gram': ['indian proverb man',
#     'restraint diet quantity',
#     'warning adopting remedy']},
#   'summarywise': {'1gram': ['diet', 'restraint', 'proverb'],
#    '2gram': ['indian proverb', 'restraint diet', 'warning adopting'],
#    '3gram': ['indian proverb man',
#     'restraint diet quantity',
#     'warning adopting remedy']}},
#  '1914': {'chapterwise': {'1gram': ['prejudice', 'stenographer', 'consult'],
#    '2gram': ['indian clerks', 'typewriting knew', 'urged scolding'],
#    '3gram': ['indian clerks like',
#     'presence wife suffered',
#     'created urged scolding']},
#   'summarywise': {'1gram': ['prejudice', 'stenographer', 'consult'],
#    '2gram': ['indian clerks', 'typewriting knew', 'urged scolding'],
#    '3gram': ['indian clerks like',
#     'presence wife suffered',
#     'created urged scolding']}},
#  '1904': {'chapterwise': {'1gram': ['plague', 'municipality', 'deposit'],
#    '2gram': ['regarding plague',
#     'commission indians',
#     'municipality hesitated'],
#    '3gram': ['black plague dealt',
#     'submit theâ municipality',
#     'banks means anxious']},
#   'summarywise': {'1gram': ['plague', 'municipality', 'deposit'],
#    '2gram': ['regarding plague',
#     'commission indians',
#     'municipality hesitated'],
#    '3gram': ['black plague dealt',
#     'submit theâ municipality',
#     'banks means anxious']}},
#  '1900': {'chapterwise': {'1gram': ['brahmacharya', 'thoughts', 'zulu'],
#    '2gram': ['praise brahmacharya',
#     'zulu rebellion',
#     'consistent imagination'],
#    '3gram': ['extravagant praise brahmacharya',
#     'lock undesirable thoughts',
#     'zulu rebellion new']},
#   'summarywise': {'1gram': ['brahmacharya', 'thoughts', 'zulu'],
#    '2gram': ['praise brahmacharya',
#     'zulu rebellion',
#     'consistent imagination'],
#    '3gram': ['extravagant praise brahmacharya',
#     'lock undesirable thoughts',
#     'zulu rebellion new']}},
#  '1912': {'chapterwise': {'1gram': ['kasturbai', 'diet', 'restraint'],
#    '2gram': ['kasturbai illness', 'consciously unclean', 'cows buffaloes'],
#    '3gram': ['chapter kasturbai illness',
#     'necessity avoiding milk',
#     'restraint used fasting']},
#   'summarywise': {'1gram': ['kasturbai', 'diet', 'restraint'],
#    '2gram': ['kasturbai illness', 'consciously unclean', 'cows buffaloes'],
#    '3gram': ['chapter kasturbai illness',
#     'necessity avoiding milk',
#     'restraint used fasting']}},
#  '1911': {'chapterwise': {'1gram': ['urdu', 'teach', 'tolstoy'],
#    '2gram': ['teach musalman', 'urdu script', 'successful literary'],
#    '3gram': ['literary training difficult',
#     'musalman boys urdu',
#     'tolstoy farm incidentally']},
#   'summarywise': {'1gram': ['urdu', 'teach', 'tolstoy'],
#    '2gram': ['teach musalman', 'urdu script', 'successful literary'],
#    '3gram': ['literary training difficult',
#     'musalman boys urdu',
#     'tolstoy farm incidentally']}},
#  '1915': {'chapterwise': {'1gram': ['gujaratis', 'pilgrimage', 'reconciled'],
#    '2gram': ['arrived gujaratis', 'reconciled protest', 'expenses ashram'],
#    '3gram': ['arrived gujaratis let',
#     'member opposition justified',
#     'expenses ashram house']},
#   'summarywise': {'1gram': ['gujaratis', 'pilgrimage', 'reconciled'],
#    '2gram': ['arrived gujaratis', 'reconciled protest', 'expenses ashram'],
#    '3gram': ['arrived gujaratis let',
#     'member opposition justified',
#     'expenses ashram house']}},
#  '1917': {'chapterwise': {'1gram': ['bihar', 'champaran', 'indigo'],
#    '2gram': ['indigo plantations', 'poor rajkumar', 'visit champaran'],
#    '3gram': ['used indigo plantations',
#     'rajkumar menial strict',
#     'personally visit champaran']},
#   'summarywise': {'1gram': ['bihar', 'champaran', 'indigo'],
#    '2gram': ['indigo plantations', 'poor rajkumar', 'visit champaran'],
#    '3gram': ['used indigo plantations',
#     'rajkumar menial strict',
#     'personally visit champaran']}},
#  '1919': {'chapterwise': {'1gram': ['pledges', 'fasting', 'mills'],
#    '2gram': ['minister pledge', 'leave mills', 'monstrous fast'],
#    '3gram': ['hands taken pledge',
#     'employment strikers municipality',
#     'food monstrous fast']},
#   'summarywise': {'1gram': ['pledges', 'fasting', 'mills'],
#    '2gram': ['minister pledge', 'leave mills', 'monstrous fast'],
#    '3gram': ['hands taken pledge',
#     'employment strikers municipality',
#     'food monstrous fast']}},
#  '1908': {'chapterwise': {'1gram': ['gandhi', 'boycott', 'deliberations'],
#    '2gram': ['happened punjab', 'boycott committee', 'regard religious'],
#    '3gram': ['responsible happened punjab',
#     'boycott committee absolutely',
#     'stopped cow slaughter']},
#   'summarywise': {'1gram': ['gandhi', 'boycott', 'deliberations'],
#    '2gram': ['happened punjab', 'boycott committee', 'regard religious'],
#    '3gram': ['responsible happened punjab',
#     'boycott committee absolutely',
#     'stopped cow slaughter']}},
#  '1920': {'chapterwise': {'1gram': ['cloth', 'swadeshi', 'demand'],
#    '2gram': ['swadeshi cloth', 'india production', 'congratulated mills'],
#    '3gram': ['india production cloth',
#     'swadeshi largely resolves',
#     'congratulated mills want']},
#   'summarywise': {'1gram': ['cloth', 'swadeshi', 'demand'],
#    '2gram': ['swadeshi cloth', 'india production', 'congratulated mills'],
#    '3gram': ['india production cloth',
#     'swadeshi largely resolves',
#     'congratulated mills want']}},
#  '1921': {'chapterwise': {'1gram': ['salvation', 'purification', 'ahimsa'],
#    '2gram': ['purification self', 'faithful narrative', 'history congress'],
#    '3gram': ['indescribable lustre truth',
#     'self purification observance',
#     'congress leaders hardly']},
#   'summarywise': {'1gram': ['salvation', 'purification', 'ahimsa'],
#    '2gram': ['purification self', 'faithful narrative', 'history congress'],
#    '3gram': ['indescribable lustre truth',
#     'self purification observance',
#     'congress leaders hardly']}}}

# %%
def get_timeline_interval_content(interval,year_to_content):
    year_to_content = {int(k):v for k,v in year_to_content.items()}
    # initialization
    year_to_content_new = {}
    for k,v in year_to_content.items():
        now = k+interval
        if k in range(k,now):
            year_to_content_new[str(k)+'-'+str(now)] =" "


    for k,v in year_to_content.items():
        now = k+interval
        if k in range(k,now):
            year_to_content_new[str(k)+'-'+str(now)] += year_to_content[k]

    return year_to_content_new

year_to_content_lsts = []
for i in range(1,6):
    year_to_content_lsts.append(get_timeline_interval_content(i,year_to_content))

# %%
year_to_content_new = {}
for l in year_to_content_lsts:
    year_to_content_new.update(l)

# %%
year_to_content_new.keys()
# Out:
# dict_keys(['1857-1858', '1869-1870', '1887-1888', '1888-1889', '1890-1891', '1891-1892', '1893-1894', '1894-1895', '1896-1897', '1897-1898', '1898-1899', '1900-1901', '1901-1902', '1904-1905', '1906-1907', '1908-1909', '1911-1912', '1912-1913', '1914-1915', '1915-1916', '1917-1918', '1919-1920', '1920-1921', '1921-1922', '1924-1925', '1857-1859', '1869-1871', '1887-1889', '1888-1890', '1890-1892', '1891-1893', '1893-1895', '1894-1896', '1896-1898', '1897-1899', '1898-1900', '1900-1902', '1901-1903', '1904-1906', '1906-1908', '1908-1910', '1911-1913', '1912-1914', '1914-1916', '1915-1917', '1917-1919', '1919-1921', '1920-1922', '1921-1923', '1924-1926', '1857-1860', '1869-1872', '1887-1890', '1888-1891', '1890-1893', '1891-1894', '1893-1896', '1894-1897', '1896-1899', '1897-1900', '1898-1901', '1900-1903', '1901-1904', '1904-1907', '1906-1909', '1908-1911', '1911-1914', '1912-1915', '1914-1917', '1915-1918', '1917-1920', '1919-1922', '1920-1923', '1921-1924', '1924-1927', '1857-1861', '1869-1873', '1887-1891', '1888-1892', '1890-1894', '1891-1895', '1893-1897', '1894-1898', '1896-1900', '1897-1901', '1898-1902', '1900-1904', '1901-1905', '1904-1908', '1906-1910', '1908-1912', '1911-1915', '1912-1916', '1914-1918', '1915-1919', '1917-1921', '1919-1923', '1920-1924', '1921-1925', '1924-1928', '1857-1862', '1869-1874', '1887-1892', '1888-1893', '1890-1895', '1891-1896', '1893-1898', '1894-1899', '1896-1901', '1897-1902', '1898-1903', '1900-1905', '1901-1906', '1904-1909', '1906-1911', '1908-1913', '1911-1916', '1912-1917', '1914-1919', '1915-1920', '1917-1922', '1919-1924', '1920-1925', '1921-1926', '1924-1929'])

# %%
from summarizer import Summarizer,TransformerSummarizer
year_to_summarizer_new = {}

bert_model = Summarizer()

for key in year_to_content_new.keys():
    year_to_summarizer_new[key] = ''.join(bert_model(year_to_content_new[key], min_length=40))
# Out:
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [55], in <cell line: 6>()
#       4 bert_model = Summarizer()
#       6 for key in year_to_content_new.keys():
# ----> 7     year_to_summarizer_new[key] = ''.join(bert_model(year_to_content_new[key], min_length=40))
#
# File ~\anaconda3\lib\site-packages\summarizer\summary_processor.py:234, in SummaryProcessor.__call__(self, body, ratio, min_length, max_length, use_first, algorithm, num_sentences, return_as_list)
#     209 def __call__(
#     210     self,
#     211     body: str,
#    (...)
#     218     return_as_list: bool = False,
#     219 ) -> str:
#     220     """
#     221     (utility that wraps around the run function)
#     222     Preprocesses the sentences, runs the clusters to find the centroids, then combines the sentences.
#    (...)
#     232     :return: A summary sentence.
#     233     """
# --> 234     return self.run(body, ratio, min_length, max_length,
#     235                     use_first, algorithm, num_sentences, return_as_list)
#
# File ~\anaconda3\lib\site-packages\summarizer\summary_processor.py:202, in SummaryProcessor.run(self, body, ratio, min_length, max_length, use_first, algorithm, num_sentences, return_as_list)
#     199 sentences = self.sentence_handler(body, min_length, max_length)
#     201 if sentences:
# --> 202     sentences, _ = self.cluster_runner(sentences, ratio, algorithm, use_first, num_sentences)
#     204 if return_as_list:
#     205     return sentences
#
# File ~\anaconda3\lib\site-packages\summarizer\summary_processor.py:108, in SummaryProcessor.cluster_runner(self, sentences, ratio, algorithm, use_first, num_sentences)
#      97 """
#      98 Runs the cluster algorithm based on the hidden state. Returns both the embeddings and sentences.
#      99
#    (...)
#     105 :return: A tuple of summarized sentences and embeddings
#     106 """
#     107 first_embedding = None
# --> 108 hidden = self.model(sentences)
#     110 if use_first:
#     111     num_sentences = num_sentences - 1 if num_sentences else num_sentences
#
# File ~\anaconda3\lib\site-packages\summarizer\transformer_embeddings\bert_embedding.py:173, in BertEmbedding.__call__(self, content, hidden, reduce_option, hidden_concat)
#     157 def __call__(
#     158     self,
#     159     content: List[str],
#    (...)
#     162     hidden_concat: bool = False,
#     163 ) -> ndarray:
#     164     """
#     165     Create matrix from the embeddings.
#     166
#    (...)
#     171     :return: A numpy array matrix of the given content.
#     172     """
# --> 173     return self.create_matrix(content, hidden, reduce_option, hidden_concat)
#
# File ~\anaconda3\lib\site-packages\summarizer\transformer_embeddings\bert_embedding.py:151, in BertEmbedding.create_matrix(self, content, hidden, reduce_option, hidden_concat)
#     134 def create_matrix(
#     135     self,
#     136     content: List[str],
#    (...)
#     139     hidden_concat: bool = False,
#     140 ) -> ndarray:
#     141     """
#     142     Create matrix from the embeddings.
#     143
#    (...)
#     148     :return: A numpy array matrix of the given content.
#     149     """
# --> 151     return np.asarray([
#     152         np.squeeze(self.extract_embeddings(
#     153             t, hidden=hidden, reduce_option=reduce_option, hidden_concat=hidden_concat
#     154         ).data.cpu().numpy()) for t in content
#     155     ])
#
# File ~\anaconda3\lib\site-packages\summarizer\transformer_embeddings\bert_embedding.py:152, in <listcomp>(.0)
#     134 def create_matrix(
#     135     self,
#     136     content: List[str],
#    (...)
#     139     hidden_concat: bool = False,
#     140 ) -> ndarray:
#     141     """
#     142     Create matrix from the embeddings.
#     143
#    (...)
#     148     :return: A numpy array matrix of the given content.
#     149     """
#     151     return np.asarray([
# --> 152         np.squeeze(self.extract_embeddings(
#     153             t, hidden=hidden, reduce_option=reduce_option, hidden_concat=hidden_concat
#     154         ).data.cpu().numpy()) for t in content
#     155     ])
#
# File ~\anaconda3\lib\site-packages\summarizer\transformer_embeddings\bert_embedding.py:108, in BertEmbedding.extract_embeddings(self, text, hidden, reduce_option, hidden_concat)
#      98 """
#      99 Extracts the embeddings for the given text.
#     100
#    (...)
#     105 :return: A torch vector.
#     106 """
#     107 tokens_tensor = self.tokenize_input(text)
# --> 108 pooled, hidden_states = self.model(tokens_tensor)[-2:]
#     110 # deprecated temporary keyword functions.
#     111 if reduce_option == 'concat_last_4':
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\bert\modeling_bert.py:1018, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1009 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#    1011 embedding_output = self.embeddings(
#    1012     input_ids=input_ids,
#    1013     position_ids=position_ids,
#    (...)
#    1016     past_key_values_length=past_key_values_length,
#    1017 )
# -> 1018 encoder_outputs = self.encoder(
#    1019     embedding_output,
#    1020     attention_mask=extended_attention_mask,
#    1021     head_mask=head_mask,
#    1022     encoder_hidden_states=encoder_hidden_states,
#    1023     encoder_attention_mask=encoder_extended_attention_mask,
#    1024     past_key_values=past_key_values,
#    1025     use_cache=use_cache,
#    1026     output_attentions=output_attentions,
#    1027     output_hidden_states=output_hidden_states,
#    1028     return_dict=return_dict,
#    1029 )
#    1030 sequence_output = encoder_outputs[0]
#    1031 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\bert\modeling_bert.py:607, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     598     layer_outputs = torch.utils.checkpoint.checkpoint(
#     599         create_custom_forward(layer_module),
#     600         hidden_states,
#    (...)
#     604         encoder_attention_mask,
#     605     )
#     606 else:
# --> 607     layer_outputs = layer_module(
#     608         hidden_states,
#     609         attention_mask,
#     610         layer_head_mask,
#     611         encoder_hidden_states,
#     612         encoder_attention_mask,
#     613         past_key_value,
#     614         output_attentions,
#     615     )
#     617 hidden_states = layer_outputs[0]
#     618 if use_cache:
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\bert\modeling_bert.py:493, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     481 def forward(
#     482     self,
#     483     hidden_states: torch.Tensor,
#    (...)
#     490 ) -> Tuple[torch.Tensor]:
#     491     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     492     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 493     self_attention_outputs = self.attention(
#     494         hidden_states,
#     495         attention_mask,
#     496         head_mask,
#     497         output_attentions=output_attentions,
#     498         past_key_value=self_attn_past_key_value,
#     499     )
#     500     attention_output = self_attention_outputs[0]
#     502     # if decoder, the last output is tuple of self-attn cache
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\bert\modeling_bert.py:432, in BertAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     413 def forward(
#     414     self,
#     415     hidden_states: torch.Tensor,
#    (...)
#     421     output_attentions: Optional[bool] = False,
#     422 ) -> Tuple[torch.Tensor]:
#     423     self_outputs = self.self(
#     424         hidden_states,
#     425         attention_mask,
#    (...)
#     430         output_attentions,
#     431     )
# --> 432     attention_output = self.output(self_outputs[0], hidden_states)
#     433     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#     434     return outputs
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\transformers\models\bert\modeling_bert.py:382, in BertSelfOutput.forward(self, hidden_states, input_tensor)
#     381 def forward(self, hidden_states: torch.Tensor, input_tensor: torch.Tensor) -> torch.Tensor:
# --> 382     hidden_states = self.dense(hidden_states)
#     383     hidden_states = self.dropout(hidden_states)
#     384     hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
year_to_summarizer_new.keys()
# Out:
# dict_keys(['1857-1858', '1860-1861', '1869-1870', '1887-1888', '1888-1889', '1890-1891', '1891-1892', '1893-1894', '1894-1895', '1896-1897', '1897-1898', '1900-1901', '1901-1902', '1904-1905', '1906-1907', '1908-1909', '1911-1912', '1912-1913', '1914-1915', '1915-1916', '1917-1918', '1919-1920', '1920-1921', '1921-1922', '1924-1925', '1857-1859', '1860-1862', '1869-1871', '1887-1889', '1888-1890', '1890-1892', '1891-1893', '1893-1895', '1894-1896', '1896-1898', '1897-1899', '1900-1902', '1901-1903', '1904-1906', '1906-1908', '1908-1910', '1911-1913', '1912-1914', '1914-1916', '1915-1917', '1917-1919', '1919-1921', '1920-1922', '1921-1923', '1924-1926', '1857-1860', '1860-1863', '1869-1872', '1887-1890', '1888-1891', '1890-1893', '1891-1894', '1893-1896', '1894-1897', '1896-1899', '1897-1900', '1900-1903', '1901-1904', '1904-1907', '1906-1909', '1908-1911', '1911-1914', '1912-1915', '1914-1917', '1915-1918', '1917-1920', '1919-1922', '1920-1923', '1921-1924', '1924-1927', '1857-1861', '1860-1864', '1869-1873', '1887-1891', '1888-1892', '1890-1894', '1891-1895', '1893-1897', '1894-1898', '1896-1900', '1897-1901', '1900-1904', '1901-1905', '1904-1908', '1906-1910', '1908-1912', '1911-1915', '1912-1916', '1914-1918', '1915-1919', '1917-1921', '1919-1923', '1920-1924', '1921-1925', '1924-1928', '1857-1862', '1860-1865', '1869-1874', '1887-1892', '1888-1893', '1890-1895', '1891-1896', '1893-1898', '1894-1899'])

# %%
with open("temporal_year_to_summarizer.json", "w") as outfile:
    json.dump(year_to_summarizer_new, outfile)

# %%
with open('temporal_year_to_summarizer.json') as json_file:
    year_to_summarizer_new = json.load(json_file)

# %%
year_to_content_new.keys()
# Out:
# dict_keys(['1857-1858', '1869-1870', '1887-1888', '1888-1889', '1890-1891', '1891-1892', '1893-1894', '1894-1895', '1896-1897', '1897-1898', '1898-1899', '1900-1901', '1901-1902', '1904-1905', '1906-1907', '1908-1909', '1911-1912', '1912-1913', '1914-1915', '1915-1916', '1917-1918', '1919-1920', '1920-1921', '1921-1922', '1924-1925', '1857-1859', '1869-1871', '1887-1889', '1888-1890', '1890-1892', '1891-1893', '1893-1895', '1894-1896', '1896-1898', '1897-1899', '1898-1900', '1900-1902', '1901-1903', '1904-1906', '1906-1908', '1908-1910', '1911-1913', '1912-1914', '1914-1916', '1915-1917', '1917-1919', '1919-1921', '1920-1922', '1921-1923', '1924-1926', '1857-1860', '1869-1872', '1887-1890', '1888-1891', '1890-1893', '1891-1894', '1893-1896', '1894-1897', '1896-1899', '1897-1900', '1898-1901', '1900-1903', '1901-1904', '1904-1907', '1906-1909', '1908-1911', '1911-1914', '1912-1915', '1914-1917', '1915-1918', '1917-1920', '1919-1922', '1920-1923', '1921-1924', '1924-1927', '1857-1861', '1869-1873', '1887-1891', '1888-1892', '1890-1894', '1891-1895', '1893-1897', '1894-1898', '1896-1900', '1897-1901', '1898-1902', '1900-1904', '1901-1905', '1904-1908', '1906-1910', '1908-1912', '1911-1915', '1912-1916', '1914-1918', '1915-1919', '1917-1921', '1919-1923', '1920-1924', '1921-1925', '1924-1928', '1857-1862', '1869-1874', '1887-1892', '1888-1893', '1890-1895', '1891-1896', '1893-1898', '1894-1899', '1896-1901', '1897-1902', '1898-1903', '1900-1905', '1901-1906', '1904-1909', '1906-1911', '1908-1913', '1911-1916', '1912-1917', '1914-1919', '1915-1920', '1917-1922', '1919-1924', '1920-1925', '1921-1926', '1924-1929'])

# %%
year_to_summarizer_new.keys()
# Out:
# dict_keys(['1857-1858', '1860-1861', '1869-1870', '1887-1888', '1888-1889', '1890-1891', '1891-1892', '1893-1894', '1894-1895', '1896-1897', '1897-1898', '1900-1901', '1901-1902', '1904-1905', '1906-1907', '1908-1909', '1911-1912', '1912-1913', '1914-1915', '1915-1916', '1917-1918', '1919-1920', '1920-1921', '1921-1922', '1924-1925', '1857-1859', '1860-1862', '1869-1871', '1887-1889', '1888-1890', '1890-1892', '1891-1893', '1893-1895', '1894-1896', '1896-1898', '1897-1899', '1900-1902', '1901-1903', '1904-1906', '1906-1908', '1908-1910', '1911-1913', '1912-1914', '1914-1916', '1915-1917', '1917-1919', '1919-1921', '1920-1922', '1921-1923', '1924-1926', '1857-1860', '1860-1863', '1869-1872', '1887-1890', '1888-1891', '1890-1893', '1891-1894', '1893-1896', '1894-1897', '1896-1899', '1897-1900', '1900-1903', '1901-1904', '1904-1907', '1906-1909', '1908-1911', '1911-1914', '1912-1915', '1914-1917', '1915-1918', '1917-1920', '1919-1922', '1920-1923', '1921-1924', '1924-1927', '1857-1861', '1860-1864', '1869-1873', '1887-1891', '1888-1892', '1890-1894', '1891-1895', '1893-1897', '1894-1898', '1896-1900', '1897-1901', '1900-1904', '1901-1905', '1904-1908', '1906-1910', '1908-1912', '1911-1915', '1912-1916', '1914-1918', '1915-1919', '1917-1921', '1919-1923', '1920-1924', '1921-1925', '1924-1928', '1857-1862', '1860-1865', '1869-1874', '1887-1892', '1888-1893', '1890-1895', '1891-1896', '1893-1898', '1894-1899'])

# %%
year = {
        "chapterwise": {
            "1gram":[],
            "2gram":[],
            "3gram":[]
        },
        "summarywise":{
            "1gram":[],
            "2gram":[],
            "3gram":[]     
        }
}

data2 = {}    
    
for key in year_to_summarizer_new.keys():
    print(key)
    data2[key] = year
    onegram_keywords,twogram_keywords,threegram_keywords = extract_keyword_from_date(year_to_summarizer_new[key])
    onegram_keywords2,twogram_keywords2,threegram_keywords2 = extract_keyword_from_date(year_to_content_new[key])
    #year_to_content[key]
    data2 = copy.deepcopy(data2)
    data2[key]["chapterwise"]['1gram'] = onegram_keywords2
    data2[key]["chapterwise"]['2gram'] = twogram_keywords2
    data2[key]["chapterwise"]['3gram'] = threegram_keywords2
    data2[key]["summarywise"]['1gram'] = onegram_keywords
    data2[key]["summarywise"]['2gram'] = twogram_keywords
    data2[key]["summarywise"]['3gram'] = threegram_keywords
# Out:
# 1857-1858
# 1860-1861
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [26], in <cell line: 16>()
#      18 data2[key] = year
#      19 onegram_keywords,twogram_keywords,threegram_keywords = extract_keyword_from_date(year_to_summarizer_new[key])
# ---> 20 onegram_keywords2,twogram_keywords2,threegram_keywords2 = extract_keyword_from_date(year_to_content_new[key])
#      21 #year_to_content[key]
#      22 data2 = copy.deepcopy(data2)
#
# KeyError: '1860-1861'

# %%
with open("temporal_year_to_all_keywords.json", "w") as outfile:
    json.dump(data2, outfile)

# %%
data2
# Out:
# {'1857-1858': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1860-1861': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1869-1870': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1887-1888': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1888-1889': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1890-1891': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1891-1892': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1893-1894': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1894-1895': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1896-1897': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1897-1898': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1900-1901': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1901-1902': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1904-1905': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1906-1907': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1908-1909': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1911-1912': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1912-1913': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1914-1915': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1915-1916': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1917-1918': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1919-1920': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1920-1921': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1921-1922': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1924-1925': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1857-1859': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1860-1862': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1869-1871': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1887-1889': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1888-1890': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1890-1892': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1891-1893': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1893-1895': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1894-1896': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1896-1898': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1897-1899': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1900-1902': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1901-1903': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1904-1906': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1906-1908': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1908-1910': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1911-1913': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1912-1914': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1914-1916': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1915-1917': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1917-1919': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1919-1921': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1920-1922': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1921-1923': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1924-1926': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1857-1860': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1860-1863': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1869-1872': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1887-1890': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1888-1891': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1890-1893': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1891-1894': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1893-1896': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1894-1897': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1896-1899': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1897-1900': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1900-1903': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1901-1904': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1904-1907': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1906-1909': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1908-1911': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1911-1914': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1912-1915': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1914-1917': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1915-1918': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1917-1920': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1919-1922': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1920-1923': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1921-1924': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1924-1927': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1857-1861': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1860-1864': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1869-1873': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1887-1891': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1888-1892': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1890-1894': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1891-1895': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1893-1897': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1894-1898': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1896-1900': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1897-1901': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1900-1904': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1901-1905': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1904-1908': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1906-1910': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1908-1912': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1911-1915': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1912-1916': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1914-1918': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1915-1919': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1917-1921': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1919-1923': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1920-1924': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1921-1925': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1924-1928': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1857-1862': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1860-1865': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1869-1874': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1887-1892': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1888-1893': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1890-1895': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1891-1896': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1893-1898': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}},
#  '1894-1899': {'chapterwise': {'1gram': ['congress', 'natal', 'pandit'],
#    '2gram': ['indian congress', 'organization permanent', 'stay natal'],
#    '3gram': ['natal indian congress',
#     'bring permanent organization',
#     'agitation started 1894']},
#   'summarywise': {'1gram': ['mahatmaship', 'meetings', 'indentured'],
#    '2gram': ['mahatmaship', 'practice lawyer', 'congress knew'],
#    '3gram': ['congress life india',
#     'aided agitation started',
#     'belaboured master liable']}}}

# %%
year_to_all_keywords.update(data2)

# %%
year_to_all_keywords.keys()
# Out:
# dict_keys(['1857', '1860', '1869', '1887', '1888', '1890', '1891', '1893', '1894', '1896', '1897', '1900', '1901', '1904', '1906', '1908', '1911', '1912', '1914', '1915', '1917', '1919', '1920', '1921', '1924', '1857-1858', '1860-1861', '1869-1870', '1887-1888', '1888-1889', '1890-1891', '1891-1892', '1893-1894', '1894-1895', '1896-1897', '1897-1898', '1900-1901', '1901-1902', '1904-1905', '1906-1907', '1908-1909', '1911-1912', '1912-1913', '1914-1915', '1915-1916', '1917-1918', '1919-1920', '1920-1921', '1921-1922', '1924-1925', '1857-1859', '1860-1862', '1869-1871', '1887-1889', '1888-1890', '1890-1892', '1891-1893', '1893-1895', '1894-1896', '1896-1898', '1897-1899', '1900-1902', '1901-1903', '1904-1906', '1906-1908', '1908-1910', '1911-1913', '1912-1914', '1914-1916', '1915-1917', '1917-1919', '1919-1921', '1920-1922', '1921-1923', '1924-1926', '1857-1860', '1860-1863', '1869-1872', '1887-1890', '1888-1891', '1890-1893', '1891-1894', '1893-1896', '1894-1897', '1896-1899', '1897-1900', '1900-1903', '1901-1904', '1904-1907', '1906-1909', '1908-1911', '1911-1914', '1912-1915', '1914-1917', '1915-1918', '1917-1920', '1919-1922', '1920-1923', '1921-1924', '1924-1927', '1857-1861', '1860-1864', '1869-1873', '1887-1891', '1888-1892', '1890-1894', '1891-1895', '1893-1897', '1894-1898', '1896-1900', '1897-1901', '1900-1904', '1901-1905', '1904-1908', '1906-1910', '1908-1912', '1911-1915', '1912-1916', '1914-1918', '1915-1919', '1917-1921', '1919-1923', '1920-1924', '1921-1925', '1924-1928', '1857-1862', '1860-1865', '1869-1874', '1887-1892', '1888-1893', '1890-1895', '1891-1896', '1893-1898', '1894-1899'])

# %%
with open("final_13_jan.json", "w") as outfile:
    json.dump(year_to_all_keywords, outfile)
